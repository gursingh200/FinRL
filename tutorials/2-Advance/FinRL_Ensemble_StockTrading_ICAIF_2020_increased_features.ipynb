# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.getcwd()
import sys
sys.path.append('../../../FinRL/')

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
TRAIN_START_DATE = '2009-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (96942, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close       volume   tic  \
# 0  2009-04-01   3.717500   3.892857   3.710357   3.308904  589372000.0  AAPL
# 1  2009-04-01  48.779999  48.930000  47.099998  36.228386   10850100.0  AMGN
# 2  2009-04-01  13.340000  14.640000  13.080000  11.772776   27701800.0   AXP
# 3  2009-04-01  34.520000  35.599998  34.209999  26.850763    9288800.0    BA
# 4  2009-04-01  27.500000  29.520000  27.440001  19.820402   15308300.0   CAT
#
#    day
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2

# %%
df.tail()
# Out:
#              date        open        high         low       close      volume  \
# 96937  2022-05-31  503.619995  504.109985  495.660004  491.949799   4003100.0
# 96938  2022-05-31  210.380005  214.350006  209.110001  211.322525   9586400.0
# 96939  2022-05-31   51.259998   51.560001   50.849998   49.813236  25016600.0
# 96940  2022-05-31   43.480000   44.270000   43.049999   42.811329   8192000.0
# 96941  2022-05-31  127.459999  129.899994  127.419998  127.591217  12304100.0
#
#        tic  day
# 96937  UNH    1
# 96938    V    1
# 96939   VZ    1
# 96940  WBA    1
# 96941  WMT    1

# %%
df.shape
# Out:
# (96942, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close       volume   tic  \
# 0  2009-04-01   3.717500   3.892857   3.710357   3.308904  589372000.0  AAPL
# 1  2009-04-01  48.779999  48.930000  47.099998  36.228386   10850100.0  AMGN
# 2  2009-04-01  13.340000  14.640000  13.080000  11.772776   27701800.0   AXP
# 3  2009-04-01  34.520000  35.599998  34.209999  26.850763    9288800.0    BA
# 4  2009-04-01  27.500000  29.520000  27.440001  19.820402   15308300.0   CAT
#
#    day
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2

# %%
len(df.tic.unique())
# Out:
# 30

# %%
df.tic.value_counts()
# Out:
# AAPL    3315
# AMGN    3315
# WMT     3315
# WBA     3315
# VZ      3315
# V       3315
# UNH     3315
# TRV     3315
# PG      3315
# NKE     3315
# MSFT    3315
# MRK     3315
# MMM     3315
# MCD     3315
# KO      3315
# JPM     3315
# JNJ     3315
# INTC    3315
# IBM     3315
# HON     3315
# HD      3315
# GS      3315
# DIS     3315
# CVX     3315
# CSCO    3315
# CRM     3315
# CAT     3315
# BA      3315
# AXP     3315
# DOW      807
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = True)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index
# Successfully added user defined features

# %%
processed.sample(5)
# Out:
#              date        open        high         low       close  \
# 18125  2011-09-22   14.322500   14.636429   14.167857   12.232808
# 49221  2015-12-28  106.500000  108.199997  106.330002  101.184280
# 66133  2018-04-23   51.689999   51.889999   50.849998   44.789246
# 42034  2015-01-02   36.669998   37.160000   36.110001   28.929903
# 89166  2021-06-17  256.070007  261.750000  256.010010  257.513000
#
#             volume   tic  day      macd     boll_ub     boll_lb     rsi_30  \
# 18125  968480800.0  AAPL  3.0  0.256065   12.607143   11.104747  57.571635
# 49221    9092700.0   DIS  0.0 -1.713321  109.651682   98.549670  45.642509
# 66133   21706700.0  INTC  0.0  0.546667   47.410689   42.350117  53.010210
# 42034   23605600.0  INTC  4.0  0.249263   30.230445   28.321567  53.863057
# 89166   27565500.0  MSFT  3.0  2.874012  258.727052  239.466370  58.709596
#
#            cci_30      dx_30  close_30_sma  close_60_sma  turbulence  \
# 18125  125.530886   9.615724     11.682326     11.490765   51.103368
# 49221 -117.168272  28.463688    106.115989    104.994965    9.494604
# 66133    5.106749   0.074474     44.859951     43.197819   48.743101
# 42034  -18.872535  15.933731     29.192728     27.710954   12.701470
# 89166  147.043291  10.817829    246.738703    246.797845   15.925816
#
#        rolling_sum  rolling_dd
# 18125   781.989252         0.0
# 49221  1542.707151         0.0
# 66133  2473.037361         0.0
# 42034  1620.795494         0.0
# 89166  3665.824329         0.0

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  203.40316413031042
# ======Model training from:  2009-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_5
# ---------------------------------------
# | time/                 |             |
# |    fps                | 120         |
# |    iterations         | 100         |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | -0.00165    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -74.5       |
# |    reward             | -0.66684824 |
# |    std                | 0.997       |
# |    value_loss         | 7.51        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 125      |
# |    iterations         | 200      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -41      |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -48.8    |
# |    reward             | 1.828497 |
# |    std                | 0.994    |
# |    value_loss         | 1.58     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 126      |
# |    iterations         | 300      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -41      |
# |    explained_variance | 0.00293  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -263     |
# |    reward             | 3.670296 |
# |    std                | 0.994    |
# |    value_loss         | 41       |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 127         |
# |    iterations         | 400         |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -41         |
# |    explained_variance | -0.0787     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | -30.4       |
# |    reward             | -0.41493016 |
# |    std                | 0.995       |
# |    value_loss         | 4.76        |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 127           |
# |    iterations         | 500           |
# |    time_elapsed       | 19            |
# |    total_timesteps    | 2500          |
# | train/                |               |
# |    entropy_loss       | -41           |
# |    explained_variance | -0.0894       |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 499           |
# |    policy_loss        | 31.8          |
# |    reward             | -0.0013503706 |
# |    std                | 0.996         |
# |    value_loss         | 0.795         |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 128        |
# |    iterations         | 600        |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -28.5      |
# |    reward             | 0.45409137 |
# |    std                | 0.998      |
# |    value_loss         | 0.526      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 128        |
# |    iterations         | 700        |
# |    time_elapsed       | 27         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -19        |
# |    reward             | -0.9175473 |
# |    std                | 0.998      |
# |    value_loss         | 0.455      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 129        |
# |    iterations         | 800        |
# |    time_elapsed       | 30         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0.0201     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 40.5       |
# |    reward             | -1.3407682 |
# |    std                | 0.999      |
# |    value_loss         | 1.28       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 129       |
# |    iterations         | 900       |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 61.6      |
# |    reward             | 2.2391298 |
# |    std                | 1         |
# |    value_loss         | 4.94      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 129       |
# |    iterations         | 1000      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 14.2      |
# |    reward             | 1.4176399 |
# |    std                | 1         |
# |    value_loss         | 1.98      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 129        |
# |    iterations         | 1100       |
# |    time_elapsed       | 42         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | -211       |
# |    reward             | -0.7246756 |
# |    std                | 0.998      |
# |    value_loss         | 31.4       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 129        |
# |    iterations         | 1200       |
# |    time_elapsed       | 46         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | 119        |
# |    reward             | -0.7097548 |
# |    std                | 0.999      |
# |    value_loss         | 10.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 128        |
# |    iterations         | 1300       |
# |    time_elapsed       | 50         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -62.3      |
# |    reward             | 0.15141676 |
# |    std                | 0.999      |
# |    value_loss         | 3.34       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 128       |
# |    iterations         | 1400      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 108       |
# |    reward             | 0.9410304 |
# |    std                | 0.998     |
# |    value_loss         | 8.58      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 128       |
# |    iterations         | 1500      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 11        |
# |    reward             | 2.1404307 |
# |    std                | 0.999     |
# |    value_loss         | 3.98      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 128        |
# |    iterations         | 1600       |
# |    time_elapsed       | 62         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 68.3       |
# |    reward             | -1.5846317 |
# |    std                | 0.996      |
# |    value_loss         | 3.43       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 128       |
# |    iterations         | 1700      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 48.2      |
# |    reward             | 2.8197737 |
# |    std                | 0.996     |
# |    value_loss         | 7.43      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 128         |
# |    iterations         | 1800        |
# |    time_elapsed       | 69          |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -41         |
# |    explained_variance | -0.0777     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | 31          |
# |    reward             | -0.31295907 |
# |    std                | 0.995       |
# |    value_loss         | 1.72        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 128       |
# |    iterations         | 1900      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -3.33     |
# |    reward             | 1.7841152 |
# |    std                | 0.995     |
# |    value_loss         | 2.35      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 128         |
# |    iterations         | 2000        |
# |    time_elapsed       | 77          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -41         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | 6.82        |
# |    reward             | -0.34723586 |
# |    std                | 0.995       |
# |    value_loss         | 0.319       |
# ---------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-06
# A2C Sharpe Ratio:  0.393691902664832
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_5
# -----------------------------------
# | time/              |            |
# |    fps             | 139        |
# |    iterations      | 1          |
# |    time_elapsed    | 14         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.21412836 |
# -----------------------------------
# day: 2959, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4323958.55
# total_reward: 3323958.55
# total_cost: 375410.07
# total_trades: 83032
# Sharpe: 0.831
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 2           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014012509 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0109     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.95        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0186     |
# |    reward               | 0.85719466  |
# |    std                  | 1           |
# |    value_loss           | 15.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 3           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.01511871  |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00291    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 16.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0187     |
# |    reward               | -0.12448904 |
# |    std                  | 1           |
# |    value_loss           | 56          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 4           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017355062 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.017      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 32          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0186     |
# |    reward               | -5.0681496  |
# |    std                  | 1.01        |
# |    value_loss           | 43.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 111          |
# |    iterations           | 5            |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.017049957  |
# |    clip_fraction        | 0.178        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.3        |
# |    explained_variance   | -0.0125      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.26         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0187      |
# |    reward               | -0.032999743 |
# |    std                  | 1.01         |
# |    value_loss           | 23           |
# ------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  0.2090752320818418
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_126_5
# day: 2959, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 4946063.15
# total_reward: 3946063.15
# total_cost: 998.99
# total_trades: 41426
# Sharpe: 0.797
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 46       |
# |    time_elapsed    | 254      |
# |    total_timesteps | 11840    |
# | train/             |          |
# |    actor_loss      | 22.2     |
# |    critic_loss     | 521      |
# |    learning_rate   | 0.0005   |
# |    n_updates       | 8880     |
# |    reward          | 4.398937 |
# ---------------------------------
# ======DDPG Validation from:  2021-01-04 to  2021-04-06
# ======Best Model Retraining from:  2009-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# ============================================
# turbulence_threshold:  203.40316413031042
# ======Model training from:  2009-04-01 to  2021-04-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_5
# ----------------------------------------
# | time/                 |              |
# |    fps                | 109          |
# |    iterations         | 100          |
# |    time_elapsed       | 4            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -41.1        |
# |    explained_variance | -0.00652     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -7.81        |
# |    reward             | -0.029865125 |
# |    std                | 1            |
# |    value_loss         | 5.15         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 118       |
# |    iterations         | 200       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 0.322     |
# |    reward             | 2.3529608 |
# |    std                | 1         |
# |    value_loss         | 1.01      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 122       |
# |    iterations         | 300       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 4.17e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -184      |
# |    reward             | 1.4650776 |
# |    std                | 1         |
# |    value_loss         | 22.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 125        |
# |    iterations         | 400        |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0.0673     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -64.9      |
# |    reward             | -1.0823965 |
# |    std                | 0.999      |
# |    value_loss         | 2.87       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 125        |
# |    iterations         | 500        |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -55.7      |
# |    reward             | 0.24970998 |
# |    std                | 0.998      |
# |    value_loss         | 2.15       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 126        |
# |    iterations         | 600        |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -508       |
# |    reward             | -7.1064835 |
# |    std                | 0.998      |
# |    value_loss         | 256        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 126        |
# |    iterations         | 700        |
# |    time_elapsed       | 27         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -21.1      |
# |    reward             | -3.4295976 |
# |    std                | 0.997      |
# |    value_loss         | 0.484      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 127        |
# |    iterations         | 800        |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -36.6      |
# |    reward             | 0.07093738 |
# |    std                | 0.997      |
# |    value_loss         | 1.3        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 127       |
# |    iterations         | 900       |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 296       |
# |    reward             | 1.2951031 |
# |    std                | 0.998     |
# |    value_loss         | 53.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 128       |
# |    iterations         | 1000      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -9.89e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -76.4     |
# |    reward             | 0.8873465 |
# |    std                | 0.997     |
# |    value_loss         | 3.67      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 126       |
# |    iterations         | 1100      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -323      |
# |    reward             | 2.0308068 |
# |    std                | 0.995     |
# |    value_loss         | 60.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 126       |
# |    iterations         | 1200      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -55.9     |
# |    reward             | 2.2100928 |
# |    std                | 0.996     |
# |    value_loss         | 12.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 126        |
# |    iterations         | 1300       |
# |    time_elapsed       | 51         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0.178      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -17.5      |
# |    reward             | -0.7021166 |
# |    std                | 0.998      |
# |    value_loss         | 0.47       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 126        |
# |    iterations         | 1400       |
# |    time_elapsed       | 55         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.14      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 21.3       |
# |    reward             | 0.20661317 |
# |    std                | 0.999      |
# |    value_loss         | 1.71       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 127       |
# |    iterations         | 1500      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -83.8     |
# |    reward             | -2.415774 |
# |    std                | 0.998     |
# |    value_loss         | 6.95      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 127        |
# |    iterations         | 1600       |
# |    time_elapsed       | 62         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 24.6       |
# |    reward             | 0.22610627 |
# |    std                | 0.995      |
# |    value_loss         | 0.701      |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 127      |
# |    iterations         | 1700     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -41      |
# |    explained_variance | 0.0117   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -582     |
# |    reward             | 3.255315 |
# |    std                | 0.995    |
# |    value_loss         | 215      |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 127        |
# |    iterations         | 1800       |
# |    time_elapsed       | 70         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | -85.8      |
# |    reward             | 0.86902964 |
# |    std                | 0.996      |
# |    value_loss         | 10.4       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 128        |
# |    iterations         | 1900       |
# |    time_elapsed       | 73         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | 32.6       |
# |    reward             | -1.3181459 |
# |    std                | 0.998      |
# |    value_loss         | 0.982      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 129       |
# |    iterations         | 2000      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.0381   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -19.7     |
# |    reward             | 1.0135131 |
# |    std                | 0.999     |
# |    value_loss         | 0.714     |
# -------------------------------------
# ======A2C Validation from:  2021-04-06 to  2021-07-06
# A2C Sharpe Ratio:  0.1755782659009128
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_5
# ----------------------------------
# | time/              |           |
# |    fps             | 135       |
# |    iterations      | 1         |
# |    time_elapsed    | 15        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.3143266 |
# ----------------------------------
# day: 3022, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4083606.63
# total_reward: 3083606.63
# total_cost: 390048.91
# total_trades: 84432
# Sharpe: 0.793
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 2           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.022873804 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0223     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.46        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0165     |
# |    reward               | 0.9111486   |
# |    std                  | 1           |
# |    value_loss           | 10.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 3           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013835885 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0146     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 18.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.017      |
# |    reward               | 0.3798866   |
# |    std                  | 1           |
# |    value_loss           | 57.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 4           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017902007 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00422    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0188     |
# |    reward               | 0.09061916  |
# |    std                  | 1.01        |
# |    value_loss           | 45.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 5           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020410832 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0465     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.64        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0268     |
# |    reward               | 0.29179254  |
# |    std                  | 1.01        |
# |    value_loss           | 11.7        |
# -----------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  0.10731141537219771
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_189_5
# day: 3022, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5509711.44
# total_reward: 4509711.44
# total_cost: 999.00
# total_trades: 57399
# Sharpe: 0.867
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 48        |
# |    time_elapsed    | 249       |
# |    total_timesteps | 12092     |
# | train/             |           |
# |    actor_loss      | 39.2      |
# |    critic_loss     | 233       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 9069      |
# |    reward          | 7.4539824 |
# ----------------------------------
# ======DDPG Validation from:  2021-04-06 to  2021-07-06
# ======Best Model Retraining from:  2009-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# ============================================
# turbulence_threshold:  203.40316413031042
# ======Model training from:  2009-04-01 to  2021-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_252_5
# ---------------------------------------
# | time/                 |             |
# |    fps                | 104         |
# |    iterations         | 100         |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0.00272     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -87.6       |
# |    reward             | -0.18422532 |
# |    std                | 1           |
# |    value_loss         | 7.24        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 107       |
# |    iterations         | 200       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0.14      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 26.5      |
# |    reward             | 2.7490606 |
# |    std                | 1.01      |
# |    value_loss         | 0.781     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 110       |
# |    iterations         | 300       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -226      |
# |    reward             | 3.1440868 |
# |    std                | 1.01      |
# |    value_loss         | 37.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 113        |
# |    iterations         | 400        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -0.0406    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -46.2      |
# |    reward             | -0.7637011 |
# |    std                | 1.01       |
# |    value_loss         | 3.8        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 116        |
# |    iterations         | 500        |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0.21       |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 97.9       |
# |    reward             | -0.3631777 |
# |    std                | 1.01       |
# |    value_loss         | 6.32       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 119       |
# |    iterations         | 600       |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 567       |
# |    reward             | 1.0655475 |
# |    std                | 1.01      |
# |    value_loss         | 188       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 119       |
# |    iterations         | 700       |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -0.0463   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -73.3     |
# |    reward             | 1.4639231 |
# |    std                | 1.01      |
# |    value_loss         | 3.05      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 120        |
# |    iterations         | 800        |
# |    time_elapsed       | 33         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -193       |
# |    reward             | -0.2581782 |
# |    std                | 1.01       |
# |    value_loss         | 24.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 121        |
# |    iterations         | 900        |
# |    time_elapsed       | 37         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 139        |
# |    reward             | 0.57064146 |
# |    std                | 1.01       |
# |    value_loss         | 13.7       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 121      |
# |    iterations         | 1000     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -144     |
# |    reward             | -2.743   |
# |    std                | 1.01     |
# |    value_loss         | 17.2     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 121       |
# |    iterations         | 1100      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -630      |
# |    reward             | 2.7424352 |
# |    std                | 1.01      |
# |    value_loss         | 251       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 123        |
# |    iterations         | 1200       |
# |    time_elapsed       | 48         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -269       |
# |    reward             | -1.2646503 |
# |    std                | 1.01       |
# |    value_loss         | 71.8       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 124         |
# |    iterations         | 1300        |
# |    time_elapsed       | 52          |
# |    total_timesteps    | 6500        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1299        |
# |    policy_loss        | 89.3        |
# |    reward             | -0.90788513 |
# |    std                | 1.01        |
# |    value_loss         | 7.41        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 124       |
# |    iterations         | 1400      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -49.6     |
# |    reward             | 2.7603817 |
# |    std                | 1.01      |
# |    value_loss         | 6.15      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 125       |
# |    iterations         | 1500      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 68.1      |
# |    reward             | 0.6229966 |
# |    std                | 1.01      |
# |    value_loss         | 4.23      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 125       |
# |    iterations         | 1600      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -161      |
# |    reward             | 3.4238245 |
# |    std                | 1.01      |
# |    value_loss         | 61.3      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 125       |
# |    iterations         | 1700      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0.00364   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -460      |
# |    reward             | 3.0705717 |
# |    std                | 1.01      |
# |    value_loss         | 152       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 124       |
# |    iterations         | 1800      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 211       |
# |    reward             | 7.0238495 |
# |    std                | 1.01      |
# |    value_loss         | 66.2      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 124      |
# |    iterations         | 1900     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 28.3     |
# |    reward             | 0.750232 |
# |    std                | 1.01     |
# |    value_loss         | 0.652    |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 124        |
# |    iterations         | 2000       |
# |    time_elapsed       | 80         |
# |    total_timesteps    | 10000      |
# ...
# |    reward             | 4.8446574 |
# |    std                | 0.999     |
# |    value_loss         | 23.7      |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 117           |
# |    iterations         | 400           |
# |    time_elapsed       | 16            |
# |    total_timesteps    | 2000          |
# | train/                |               |
# |    entropy_loss       | -41.1         |
# |    explained_variance | 0.323         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 399           |
# |    policy_loss        | 19.2          |
# |    reward             | -0.0051347977 |
# |    std                | 0.999         |
# |    value_loss         | 1.7           |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 119        |
# |    iterations         | 500        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0.00807    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 22.4       |
# |    reward             | -2.3189726 |
# |    std                | 0.999      |
# |    value_loss         | 3.87       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 121       |
# |    iterations         | 600       |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.00768  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 421       |
# |    reward             | -7.765379 |
# |    std                | 0.998     |
# |    value_loss         | 109       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 123        |
# |    iterations         | 700        |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.141     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -77.9      |
# |    reward             | -0.8561663 |
# |    std                | 0.999      |
# |    value_loss         | 7.27       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 124         |
# |    iterations         | 800         |
# |    time_elapsed       | 32          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | 23.4        |
# |    reward             | -0.24620993 |
# |    std                | 0.999       |
# |    value_loss         | 0.972       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 125       |
# |    iterations         | 900       |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.0496   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -121      |
# |    reward             | 2.3409417 |
# |    std                | 0.999     |
# |    value_loss         | 13        |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 125        |
# |    iterations         | 1000       |
# |    time_elapsed       | 39         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.00762   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 55.8       |
# |    reward             | -0.5394367 |
# |    std                | 1          |
# |    value_loss         | 2          |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 126       |
# |    iterations         | 1100      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | 303       |
# |    reward             | 3.1323385 |
# |    std                | 1         |
# |    value_loss         | 86.3      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 126       |
# |    iterations         | 1200      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 320       |
# |    reward             | 8.895861  |
# |    std                | 1.01      |
# |    value_loss         | 120       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 126        |
# |    iterations         | 1300       |
# |    time_elapsed       | 51         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.0167     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -20.5      |
# |    reward             | -1.6448494 |
# |    std                | 1          |
# |    value_loss         | 0.378      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 125        |
# |    iterations         | 1400       |
# |    time_elapsed       | 55         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 10.3       |
# |    reward             | -0.7558319 |
# |    std                | 1          |
# |    value_loss         | 0.474      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 124        |
# |    iterations         | 1500       |
# |    time_elapsed       | 60         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | -43.6      |
# |    reward             | -0.7904881 |
# |    std                | 1          |
# |    value_loss         | 1.99       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 124        |
# |    iterations         | 1600       |
# |    time_elapsed       | 64         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 22.5       |
# |    reward             | -2.2290673 |
# |    std                | 1          |
# |    value_loss         | 3.61       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 124       |
# |    iterations         | 1700      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -29.9     |
# |    reward             | 0.7636447 |
# |    std                | 1.01      |
# |    value_loss         | 2.97      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 124         |
# |    iterations         | 1800        |
# |    time_elapsed       | 72          |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | 328         |
# |    reward             | -0.48734272 |
# |    std                | 1.01        |
# |    value_loss         | 68.3        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 124        |
# |    iterations         | 1900       |
# |    time_elapsed       | 76         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -0.772     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | -17.1      |
# |    reward             | 0.18093339 |
# |    std                | 1.01       |
# |    value_loss         | 0.202      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 123        |
# |    iterations         | 2000       |
# |    time_elapsed       | 80         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | -73.2      |
# |    reward             | -1.5255046 |
# |    std                | 1.01       |
# |    value_loss         | 3.59       |
# --------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  0.4392235324967046
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_5
# -----------------------------------
# | time/              |            |
# |    fps             | 126        |
# |    iterations      | 1          |
# |    time_elapsed    | 16         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.92893004 |
# -----------------------------------
# day: 3148, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 3081514.44
# total_reward: 2081514.44
# total_cost: 423604.14
# total_trades: 87998
# Sharpe: 0.652
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 2           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015553558 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0158     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.11        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0265     |
# |    reward               | 1.1309133   |
# |    std                  | 1           |
# |    value_loss           | 8.41        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 3           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014787549 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -3.27e-05   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 26.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0186     |
# |    reward               | 3.6344533   |
# |    std                  | 1           |
# |    value_loss           | 39.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 4           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.020101853 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0065     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 25.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0227     |
# |    reward               | -0.4192345  |
# |    std                  | 1           |
# |    value_loss           | 46          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 5           |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.022890143 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00831    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.15        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0258     |
# |    reward               | 0.52610946  |
# |    std                  | 1.01        |
# |    value_loss           | 14.1        |
# -----------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.07952879314008997
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_315_5
# day: 3148, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 4248680.56
# total_reward: 3248680.56
# total_cost: 999.00
# total_trades: 37751
# Sharpe: 0.734
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 45       |
# |    time_elapsed    | 277      |
# |    total_timesteps | 12596    |
# | train/             |          |
# |    actor_loss      | 1.38     |
# |    critic_loss     | 228      |
# |    learning_rate   | 0.0005   |
# |    n_updates       | 9447     |
# |    reward          | 7.232484 |
# ---------------------------------
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======Best Model Retraining from:  2009-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# Ensemble Strategy took:  31.015018018086753  minutes

# %%
env = StockTradingEnv
print(env.__dict__)
# Out:
# {'__module__': 'finrl.meta.env_stock_trading.env_stocktrading', '__doc__': 'A stock trading environment for OpenAI gym', 'metadata': {'render.modes': ['human']}, '__init__': <function StockTradingEnv.__init__ at 0x7efd885b35b0>, '_sell_stock': <function StockTradingEnv._sell_stock at 0x7efd885b36d0>, '_buy_stock': <function StockTradingEnv._buy_stock at 0x7efd02a60790>, '_make_plot': <function StockTradingEnv._make_plot at 0x7efd02a60c10>, 'step': <function StockTradingEnv.step at 0x7efd02a60ca0>, 'reset': <function StockTradingEnv.reset at 0x7efd02a60d30>, 'render': <function StockTradingEnv.render at 0x7efd02a60dc0>, '_initiate_state': <function StockTradingEnv._initiate_state at 0x7efd02a60e50>, '_update_state': <function StockTradingEnv._update_state at 0x7efd02a60ee0>, '_get_date': <function StockTradingEnv._get_date at 0x7efd02a60f70>, 'save_state_memory': <function StockTradingEnv.save_state_memory at 0x7efd02a61000>, 'save_asset_memory': <function StockTradingEnv.save_asset_memory at 0x7efd02a61090>, 'save_action_memory': <function StockTradingEnv.save_action_memory at 0x7efd02a61120>, '_seed': <function StockTradingEnv._seed at 0x7efd02a611b0>, 'get_sb_env': <function StockTradingEnv.get_sb_env at 0x7efd02a61240>}

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06       DDPG   0.393692   0.209075    0.396014
# 1  189  2021-04-06  2021-07-06        A2C   0.175578   0.107311    0.114349
# 2  252  2021-07-06  2021-10-04       DDPG  -0.029422  -0.047135    0.013331
# 3  315  2021-10-04  2022-01-03        A2C   0.439224   0.079529    0.284956

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.4125271170026633

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-04-06           NaN  2021-04-06
# 1   9.996592e+05  2021-04-07     -0.000341  2021-04-07
# 2   1.000933e+06  2021-04-08      0.001274  2021-04-08
# 3   1.010261e+06  2021-04-09      0.009319  2021-04-09
# 4   1.009559e+06  2021-04-12     -0.000694  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.049022
# Cumulative returns     0.049022
# Annual volatility      0.140229
# Sharpe ratio           0.412527
# Calmar ratio           0.368928
# Stability              0.000025
# Max drawdown          -0.132876
# Omega ratio            1.071156
# Sortino ratio          0.590561
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.837958
# Daily value at risk   -0.017438
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.037486
# Cumulative returns     0.037335
# Annual volatility      0.134331
# Sharpe ratio           0.342028
# Calmar ratio           0.331049
# Stability              0.066383
# Max drawdown          -0.113235
# Omega ratio            1.058031
# Sortino ratio          0.480831
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.970301
# Daily value at risk   -0.016742
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^DJI', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>4.9%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>4.9%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>14.0%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.41</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.37</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-13.3%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.07</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.59</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.84</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.7%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.97</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>13.29</td>
#       <td>2021-11-08</td>
#       <td>2022-02-23</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.71</td>
#       <td>2021-06-04</td>
#       <td>2021-06-18</td>
#       <td>2021-07-26</td>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.48</td>
#       <td>2021-09-27</td>
#       <td>2021-09-30</td>
#       <td>2021-10-19</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.43</td>
#       <td>2021-08-27</td>
#       <td>2021-09-21</td>
#       <td>2021-09-23</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.06</td>
#       <td>2021-05-10</td>
#       <td>2021-05-12</td>
#       <td>2021-06-03</td>
#       <td>19</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.02%</td>
#       <td>-2.81%</td>
#       <td>2.54%</td>
#     </tr>
#   </tbody>
# </table>
