# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# # ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.getcwd()
import sys
sys.path.append('../../../FinRL/')

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
TRAIN_START_DATE = '2009-04-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2022-06-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (96942, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close       volume   tic  \
# 0  2009-04-01   3.717500   3.892857   3.710357   3.308903  589372000.0  AAPL
# 1  2009-04-01  48.779999  48.930000  47.099998  36.228394   10850100.0  AMGN
# 2  2009-04-01  13.340000  14.640000  13.080000  11.772776   27701800.0   AXP
# 3  2009-04-01  34.520000  35.599998  34.209999  26.850744    9288800.0    BA
# 4  2009-04-01  27.500000  29.520000  27.440001  19.820398   15308300.0   CAT
#
#    day
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2

# %%
df.tail()
# Out:
#              date        open        high         low       close      volume  \
# 96937  2022-05-31  503.619995  504.109985  495.660004  491.949799   4003100.0
# 96938  2022-05-31  210.380005  214.350006  209.110001  211.322540   9586400.0
# 96939  2022-05-31   51.259998   51.560001   50.849998   49.813236  25016600.0
# 96940  2022-05-31   43.480000   44.270000   43.049999   42.811329   8192000.0
# 96941  2022-05-31  127.459999  129.899994  127.419998  127.591217  12304100.0
#
#        tic  day
# 96937  UNH    1
# 96938    V    1
# 96939   VZ    1
# 96940  WBA    1
# 96941  WMT    1

# %%
df.shape
# Out:
# (96942, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
#          date       open       high        low      close       volume   tic  \
# 0  2009-04-01   3.717500   3.892857   3.710357   3.308903  589372000.0  AAPL
# 1  2009-04-01  48.779999  48.930000  47.099998  36.228394   10850100.0  AMGN
# 2  2009-04-01  13.340000  14.640000  13.080000  11.772776   27701800.0   AXP
# 3  2009-04-01  34.520000  35.599998  34.209999  26.850744    9288800.0    BA
# 4  2009-04-01  27.500000  29.520000  27.440001  19.820398   15308300.0   CAT
#
#    day
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2

# %%
len(df.tic.unique())
# Out:
# 30

# %%
df.tic.value_counts()
# Out:
# AAPL    3315
# AMGN    3315
# WMT     3315
# WBA     3315
# VZ      3315
# V       3315
# UNH     3315
# TRV     3315
# PG      3315
# NKE     3315
# MSFT    3315
# MRK     3315
# MMM     3315
# MCD     3315
# KO      3315
# JPM     3315
# JNJ     3315
# INTC    3315
# IBM     3315
# HON     3315
# HD      3315
# GS      3315
# DIS     3315
# CVX     3315
# CSCO    3315
# CRM     3315
# CAT     3315
# BA      3315
# AXP     3315
# DOW      807
# Name: tic, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.sample(5)
# Out:
#              date        open        high         low       close     volume  \
# 35829  2014-02-27   91.160004   91.419998   90.750000   72.218269  7040300.0
# 93166  2022-01-03  178.320007  179.089996  175.839996  170.510239  1930700.0
# 28314  2013-02-15   67.519997   67.989998   66.800003   53.982010  8131200.0
# 69083  2018-09-17  157.000000  158.429993  154.619995  154.919998  3899600.0
# 59910  2017-06-14   95.320000   96.000000   94.949997   91.929955  6347000.0
#
#        tic  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 35829  JNJ    3  0.105946   74.509661   67.929834  50.900837    3.453881
# 93166  MMM    0  0.148740  172.358845  165.313561  49.589131   57.963458
# 28314   HD    4  0.635190   54.499780   52.460101  61.021206   73.690006
# 69083  CRM    0  2.697270  158.942752  144.393248  60.105979  120.536682
# 59910    V    2  0.796613   93.984886   88.497810  61.123232   76.227061
#
#            dx_30  close_30_sma  close_60_sma  turbulence
# 35829   9.820340     71.682498     72.302611   22.693557
# 93166   4.712747    168.561197    170.311416   40.620544
# 28314  27.688675     52.604492     51.544169   34.888588
# 69083  25.342912    149.460667    145.695166   17.535864
# 59910  13.111302     90.496556     88.474868   30.881618

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  203.40575466145407
# ======Model training from:  2009-04-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_4
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 100        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.0887    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | 62         |
# |    reward             | 0.36758968 |
# |    std                | 1          |
# |    value_loss         | 3.96       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 114       |
# |    iterations         | 200       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -43.5     |
# |    reward             | 2.1211123 |
# |    std                | 1         |
# |    value_loss         | 1.18      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 122      |
# |    iterations         | 300      |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | -0.14    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -160     |
# |    reward             | 1.715307 |
# |    std                | 1        |
# |    value_loss         | 20.9     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 125       |
# |    iterations         | 400       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -68       |
# |    reward             | -0.564453 |
# |    std                | 1         |
# |    value_loss         | 3.44      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 128         |
# |    iterations         | 500         |
# |    time_elapsed       | 19          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | -0.0354     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | 107         |
# |    reward             | -0.15930066 |
# |    std                | 1           |
# |    value_loss         | 11.8        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 130        |
# |    iterations         | 600        |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0.044      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -6.61      |
# |    reward             | 0.22708511 |
# |    std                | 1.01       |
# |    value_loss         | 1.55       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 131       |
# |    iterations         | 700       |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0.153     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -55.3     |
# |    reward             | -1.374948 |
# |    std                | 1         |
# |    value_loss         | 2.43      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 132         |
# |    iterations         | 800         |
# |    time_elapsed       | 30          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0.0449      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | 6.88        |
# |    reward             | -0.14587285 |
# |    std                | 1           |
# |    value_loss         | 0.155       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 132       |
# |    iterations         | 900       |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -32.8     |
# |    reward             | 2.7869766 |
# |    std                | 1.01      |
# |    value_loss         | 2.3       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 131      |
# |    iterations         | 1000     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -7.46    |
# |    reward             | 1.332787 |
# |    std                | 1        |
# |    value_loss         | 0.873    |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 131        |
# |    iterations         | 1100       |
# |    time_elapsed       | 41         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | 42.4       |
# |    reward             | -2.7511013 |
# |    std                | 1          |
# |    value_loss         | 11.2       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 131        |
# |    iterations         | 1200       |
# |    time_elapsed       | 45         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.0792     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | 137        |
# |    reward             | -0.4092638 |
# |    std                | 1          |
# |    value_loss         | 12.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 131       |
# |    iterations         | 1300      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -69.8     |
# |    reward             | 0.5110615 |
# |    std                | 1         |
# |    value_loss         | 4.02      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 131        |
# |    iterations         | 1400       |
# |    time_elapsed       | 53         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.174      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 36         |
# |    reward             | -2.3463898 |
# |    std                | 1          |
# |    value_loss         | 6.68       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 131       |
# |    iterations         | 1500      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.059     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -25.4     |
# |    reward             | 3.0572107 |
# |    std                | 1         |
# |    value_loss         | 3.34      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 131        |
# |    iterations         | 1600       |
# |    time_elapsed       | 60         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 134        |
# |    reward             | -1.7193687 |
# |    std                | 1          |
# |    value_loss         | 10.3       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 131      |
# |    iterations         | 1700     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -105     |
# |    reward             | 1.411002 |
# |    std                | 1        |
# |    value_loss         | 8.51     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 131       |
# |    iterations         | 1800      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0.028     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 23.5      |
# |    reward             | 0.8780931 |
# |    std                | 1         |
# |    value_loss         | 1.03      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 132       |
# |    iterations         | 1900      |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -43.3     |
# |    reward             | 1.5020368 |
# |    std                | 0.998     |
# |    value_loss         | 4.42      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 131         |
# |    iterations         | 2000        |
# |    time_elapsed       | 75          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | 47.9        |
# |    reward             | -0.41005057 |
# |    std                | 1           |
# |    value_loss         | 1.84        |
# ---------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-06
# A2C Sharpe Ratio:  0.408499146198392
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_4
# ----------------------------------
# | time/              |           |
# |    fps             | 131       |
# |    iterations      | 1         |
# |    time_elapsed    | 15        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.7644697 |
# ----------------------------------
# day: 2959, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 3303680.46
# total_reward: 2303680.46
# total_cost: 369310.45
# total_trades: 82486
# Sharpe: 0.689
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 2           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.019984297 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00427     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.6         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0286     |
# |    reward               | 1.4037067   |
# |    std                  | 1           |
# |    value_loss           | 11.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 3           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016088933 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.00727     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 29.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0214     |
# |    reward               | -0.14467557 |
# |    std                  | 1           |
# |    value_loss           | 42.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 4           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013718337 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.00775     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 50          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0167     |
# |    reward               | -3.393162   |
# |    std                  | 1.01        |
# |    value_loss           | 194         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 5           |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018352687 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0664     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.25        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0214     |
# |    reward               | 0.055976905 |
# |    std                  | 1.01        |
# |    value_loss           | 18.7        |
# -----------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-06
# PPO Sharpe Ratio:  0.22105608907870786
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_126_4
# day: 2959, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5359828.63
# total_reward: 4359828.63
# total_cost: 1273.95
# total_trades: 38559
# Sharpe: 0.888
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 51        |
# |    time_elapsed    | 229       |
# |    total_timesteps | 11840     |
# | train/             |           |
# |    actor_loss      | -10       |
# |    critic_loss     | 218       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 8880      |
# |    reward          | 4.0392795 |
# ----------------------------------
# ======DDPG Validation from:  2021-01-04 to  2021-04-06
# ======Best Model Retraining from:  2009-04-01 to  2021-04-06
# ======Trading from:  2021-04-06 to  2021-07-06
# ============================================
# turbulence_threshold:  203.40575466145407
# ======Model training from:  2009-04-01 to  2021-04-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_4
# --------------------------------------
# | time/                 |            |
# |    fps                | 81         |
# |    iterations         | 100        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.00603    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | 1.8        |
# |    reward             | 0.13242449 |
# |    std                | 1          |
# |    value_loss         | 2.67       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 90        |
# |    iterations         | 200       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.0154    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -64.1     |
# |    reward             | 2.9283445 |
# |    std                | 1         |
# |    value_loss         | 2.29      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 94       |
# |    iterations         | 300      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0.295    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -233     |
# |    reward             | 3.726781 |
# |    std                | 1        |
# |    value_loss         | 38.8     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 82        |
# |    iterations         | 400       |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.0757   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -71.2     |
# |    reward             | 0.5160435 |
# |    std                | 1         |
# |    value_loss         | 4.48      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 77          |
# |    iterations         | 500         |
# |    time_elapsed       | 32          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0.0266      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -66.1       |
# |    reward             | -0.68217343 |
# |    std                | 1           |
# |    value_loss         | 3.35        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 74        |
# |    iterations         | 600       |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.0124   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -19       |
# |    reward             | -4.729227 |
# |    std                | 1         |
# |    value_loss         | 12.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 700        |
# |    time_elapsed       | 48         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.21      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -32.8      |
# |    reward             | -2.3361928 |
# |    std                | 1          |
# |    value_loss         | 1.56       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 73        |
# |    iterations         | 800       |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.0786   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -8.21     |
# |    reward             | 0.8491528 |
# |    std                | 1         |
# |    value_loss         | 0.928     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 73       |
# |    iterations         | 900      |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | -0.061   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 84.3     |
# |    reward             | 4.435687 |
# |    std                | 1        |
# |    value_loss         | 6.82     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 73         |
# |    iterations         | 1000       |
# |    time_elapsed       | 68         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -3.26      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -4.52      |
# |    reward             | 0.51251495 |
# |    std                | 1          |
# |    value_loss         | 2.82       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 75        |
# |    iterations         | 1100      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.103    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -53.6     |
# |    reward             | 1.4691206 |
# |    std                | 1         |
# |    value_loss         | 2.55      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 77        |
# |    iterations         | 1200      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 67.9      |
# |    reward             | 4.0476003 |
# |    std                | 1         |
# |    value_loss         | 4.43      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 80         |
# |    iterations         | 1300       |
# |    time_elapsed       | 80         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -24.7      |
# |    reward             | -0.9723408 |
# |    std                | 1          |
# |    value_loss         | 0.749      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 82         |
# |    iterations         | 1400       |
# |    time_elapsed       | 84         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 23.8       |
# |    reward             | 0.27463263 |
# |    std                | 1          |
# |    value_loss         | 4.21       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 84         |
# |    iterations         | 1500       |
# |    time_elapsed       | 88         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | -105       |
# |    reward             | -2.5027044 |
# |    std                | 1.01       |
# |    value_loss         | 9.3        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 86       |
# |    iterations         | 1600     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.574   |
# |    reward             | 0.959453 |
# |    std                | 1.01     |
# |    value_loss         | 0.447    |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 88        |
# |    iterations         | 1700      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -357      |
# |    reward             | 2.9433556 |
# |    std                | 1.01      |
# |    value_loss         | 92.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 89         |
# |    iterations         | 1800       |
# |    time_elapsed       | 100        |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -0.000391  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | -105       |
# |    reward             | 0.62363356 |
# |    std                | 1.01       |
# |    value_loss         | 7.42       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 91          |
# |    iterations         | 1900        |
# |    time_elapsed       | 103         |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | 19          |
# |    reward             | -0.32203373 |
# |    std                | 1.01        |
# |    value_loss         | 0.357       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 92         |
# |    iterations         | 2000       |
# |    time_elapsed       | 107        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 8.36       |
# |    reward             | 0.41788182 |
# |    std                | 1.01       |
# |    value_loss         | 1.66       |
# --------------------------------------
# ======A2C Validation from:  2021-04-06 to  2021-07-06
# A2C Sharpe Ratio:  0.11810104127925053
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_4
# -----------------------------------
# | time/              |            |
# |    fps             | 136        |
# |    iterations      | 1          |
# |    time_elapsed    | 15         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.62384737 |
# -----------------------------------
# day: 3022, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4195078.40
# total_reward: 3195078.40
# total_cost: 397744.08
# total_trades: 84779
# Sharpe: 0.797
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 2           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014112508 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00192    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.71        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0249     |
# |    reward               | 0.9006091   |
# |    std                  | 1           |
# |    value_loss           | 13.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 3           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.023514297 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.000501   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 27.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0212     |
# |    reward               | 0.3871218   |
# |    std                  | 1           |
# |    value_loss           | 59.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 4           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.01214463  |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.000263   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 46.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0143     |
# |    reward               | -0.18092969 |
# |    std                  | 1           |
# |    value_loss           | 162         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 5           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.024366291 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0219     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.72        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.031      |
# |    reward               | 1.389274    |
# |    std                  | 1           |
# |    value_loss           | 8.07        |
# -----------------------------------------
# ======PPO Validation from:  2021-04-06 to  2021-07-06
# PPO Sharpe Ratio:  0.19914555796217964
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_189_4
# day: 3022, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 4216013.80
# total_reward: 3216013.80
# total_cost: 1041.05
# total_trades: 51389
# Sharpe: 0.727
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 51        |
# |    time_elapsed    | 234       |
# |    total_timesteps | 12092     |
# | train/             |           |
# |    actor_loss      | 57.3      |
# |    critic_loss     | 3.45e+03  |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 9069      |
# |    reward          | 4.4830174 |
# ----------------------------------
# ======DDPG Validation from:  2021-04-06 to  2021-07-06
# ======Best Model Retraining from:  2009-04-01 to  2021-07-06
# ======Trading from:  2021-07-06 to  2021-10-04
# ============================================
# turbulence_threshold:  203.40575466145407
# ======Model training from:  2009-04-01 to  2021-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_252_4
# --------------------------------------
# | time/                 |            |
# |    fps                | 96         |
# |    iterations         | 100        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -62.6      |
# |    reward             | -0.1870269 |
# |    std                | 1          |
# |    value_loss         | 5.04       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 200       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -89.2     |
# |    reward             | 2.9197428 |
# |    std                | 1         |
# |    value_loss         | 4.69      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 103         |
# |    iterations         | 300         |
# |    time_elapsed       | 14          |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | -192        |
# |    reward             | -0.24864078 |
# |    std                | 1           |
# |    value_loss         | 22.5        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 105         |
# |    iterations         | 400         |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | -109        |
# |    reward             | -0.45133504 |
# |    std                | 1           |
# |    value_loss         | 11.3        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 106       |
# |    iterations         | 500       |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -129      |
# |    reward             | 0.4277993 |
# |    std                | 1         |
# |    value_loss         | 12.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 103       |
# |    iterations         | 600       |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -802      |
# |    reward             | -8.193317 |
# |    std                | 1         |
# |    value_loss         | 556       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 700       |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -64.8     |
# |    reward             | 0.5251893 |
# |    std                | 1         |
# |    value_loss         | 2.3       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 98         |
# |    iterations         | 800        |
# |    time_elapsed       | 40         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -87.8      |
# |    reward             | -3.4331882 |
# |    std                | 1          |
# |    value_loss         | 5.34       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 93         |
# |    iterations         | 900        |
# |    time_elapsed       | 48         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 64         |
# |    reward             | -0.6470952 |
# |    std                | 1          |
# |    value_loss         | 3.19       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 90          |
# |    iterations         | 1000        |
# |    time_elapsed       | 55          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 999         |
# |    policy_loss        | 49          |
# |    reward             | -0.53419244 |
# |    std                | 1           |
# |    value_loss         | 1.64        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 90        |
# |    iterations         | 1100      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -42       |
# |    reward             | -4.388336 |
# |    std                | 1         |
# |    value_loss         | 1.73      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 92        |
# |    iterations         | 1200      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -155      |
# |    reward             | 1.0864862 |
# |    std                | 1         |
# |    value_loss         | 22.2      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 93         |
# |    iterations         | 1300       |
# |    time_elapsed       | 69         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.294      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 22.5       |
# |    reward             | -1.3893712 |
# |    std                | 1          |
# |    value_loss         | 0.69       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 1400      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 49.9      |
# |    reward             | 1.6514676 |
# |    std                | 1         |
# |    value_loss         | 2.91      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 96          |
# |    iterations         | 1500        |
# |    time_elapsed       | 77          |
# |    total_timesteps    | 7500        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1499        |
# |    policy_loss        | 17.9        |
# |    reward             | -0.68742555 |
# |    std                | 1           |
# |    value_loss         | 0.443       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 98        |
# |    iterations         | 1600      |
# |    time_elapsed       | 81        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 25.8      |
# |    reward             | 1.6460341 |
# |    std                | 1         |
# |    value_loss         | 1.96      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 99         |
# |    iterations         | 1700       |
# |    time_elapsed       | 85         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | 54.2       |
# |    reward             | -0.7637452 |
# |    std                | 1          |
# |    value_loss         | 2.34       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 100        |
# |    iterations         | 1800       |
# |    time_elapsed       | 89         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | -25.1      |
# |    reward             | -1.4489948 |
# |    std                | 1          |
# |    value_loss         | 7.25       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 1900      |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.0799    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 67.2      |
# |    reward             | 0.5050864 |
# |    std                | 1         |
# |    value_loss         | 2.7       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 103       |
# |    iterations         | 2000      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# ...
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -161      |
# |    reward             | 1.9362743 |
# |    std                | 1         |
# |    value_loss         | 20.4      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 90         |
# |    iterations         | 400        |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -15.9      |
# |    reward             | 0.25636217 |
# |    std                | 1          |
# |    value_loss         | 1.37       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 92        |
# |    iterations         | 500       |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.0554   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 141       |
# |    reward             | 0.9958101 |
# |    std                | 1         |
# |    value_loss         | 12.6      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 600        |
# |    time_elapsed       | 33         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -2.38e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 517        |
# |    reward             | -2.3987021 |
# |    std                | 1          |
# |    value_loss         | 163        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 700        |
# |    time_elapsed       | 40         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -102       |
# |    reward             | 0.15251693 |
# |    std                | 1          |
# |    value_loss         | 10.2       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 87          |
# |    iterations         | 800         |
# |    time_elapsed       | 45          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0.0108      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | 48.6        |
# |    reward             | 0.063339666 |
# |    std                | 1.01        |
# |    value_loss         | 1.81        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 90        |
# |    iterations         | 900       |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.0138   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -78.3     |
# |    reward             | 1.4105685 |
# |    std                | 1.01      |
# |    value_loss         | 8.65      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 92         |
# |    iterations         | 1000       |
# |    time_elapsed       | 54         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 1.79e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -36.2      |
# |    reward             | -0.7149193 |
# |    std                | 1          |
# |    value_loss         | 1.38       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 94        |
# |    iterations         | 1100      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | 289       |
# |    reward             | 0.6109149 |
# |    std                | 1         |
# |    value_loss         | 45.9      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 96       |
# |    iterations         | 1200     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 258      |
# |    reward             | 3.209774 |
# |    std                | 1        |
# |    value_loss         | 47.2     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 98         |
# |    iterations         | 1300       |
# |    time_elapsed       | 66         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.049      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -63.8      |
# |    reward             | -1.3776193 |
# |    std                | 1          |
# |    value_loss         | 2.31       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 100       |
# |    iterations         | 1400      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 29.3      |
# |    reward             | 0.8297872 |
# |    std                | 1         |
# |    value_loss         | 0.707     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 101       |
# |    iterations         | 1500      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -45       |
# |    reward             | 1.1942629 |
# |    std                | 1.01      |
# |    value_loss         | 1.64      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 103        |
# |    iterations         | 1600       |
# |    time_elapsed       | 77         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 66         |
# |    reward             | 0.05756799 |
# |    std                | 1.01       |
# |    value_loss         | 6.31       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 104         |
# |    iterations         | 1700        |
# |    time_elapsed       | 81          |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1699        |
# |    policy_loss        | 24.2        |
# |    reward             | -0.19727278 |
# |    std                | 1.01        |
# |    value_loss         | 1.73        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 105       |
# |    iterations         | 1800      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 231       |
# |    reward             | 0.7103614 |
# |    std                | 1.01      |
# |    value_loss         | 37.4      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 106         |
# |    iterations         | 1900        |
# |    time_elapsed       | 89          |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | -2.33       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | 9.17        |
# |    reward             | -0.23530981 |
# |    std                | 1.01        |
# |    value_loss         | 1.35        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 107        |
# |    iterations         | 2000       |
# |    time_elapsed       | 93         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | -81.3      |
# |    reward             | -1.4901034 |
# |    std                | 1.01       |
# |    value_loss         | 4.95       |
# --------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  0.46418081233605796
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_4
# ----------------------------------
# | time/              |           |
# |    fps             | 124       |
# |    iterations      | 1         |
# |    time_elapsed    | 16        |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.3729529 |
# ----------------------------------
# day: 3148, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 3501987.13
# total_reward: 2501987.13
# total_cost: 417675.67
# total_trades: 87651
# Sharpe: 0.681
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 2           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017027639 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00538    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.34        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0349     |
# |    reward               | 0.82502055  |
# |    std                  | 1           |
# |    value_loss           | 12.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 3           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016429376 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00284     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.05        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.019      |
# |    reward               | 7.233718    |
# |    std                  | 1           |
# |    value_loss           | 31.9        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 126        |
# |    iterations           | 4          |
# |    time_elapsed         | 65         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01724189 |
# |    clip_fraction        | 0.17       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | -0.0216    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 23.4       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0183    |
# |    reward               | -0.6655594 |
# |    std                  | 1          |
# |    value_loss           | 54.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 5           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014875976 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.0116      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.76        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0194     |
# |    reward               | 0.18723074  |
# |    std                  | 1.01        |
# |    value_loss           | 16.2        |
# -----------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.13217405222538436
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_315_4
# day: 3148, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 4607584.94
# total_reward: 3607584.94
# total_cost: 1131.93
# total_trades: 44073
# Sharpe: 0.733
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 45       |
# |    time_elapsed    | 277      |
# |    total_timesteps | 12596    |
# | train/             |          |
# |    actor_loss      | 0.462    |
# |    critic_loss     | 45.7     |
# |    learning_rate   | 0.0005   |
# |    n_updates       | 9447     |
# |    reward          | 9.050232 |
# ---------------------------------
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======Best Model Retraining from:  2009-04-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# Ensemble Strategy took:  31.1176664908727  minutes

# %%
env = StockTradingEnv
print(env.__dict__)
# Out:
# {'__module__': 'finrl.meta.env_stock_trading.env_stocktrading', '__doc__': 'A stock trading environment for OpenAI gym', 'metadata': {'render.modes': ['human']}, '__init__': <function StockTradingEnv.__init__ at 0x7f35304a7640>, '_sell_stock': <function StockTradingEnv._sell_stock at 0x7f35304a7760>, '_buy_stock': <function StockTradingEnv._buy_stock at 0x7f34aa960790>, '_make_plot': <function StockTradingEnv._make_plot at 0x7f34aa960c10>, 'step': <function StockTradingEnv.step at 0x7f34aa960ca0>, 'reset': <function StockTradingEnv.reset at 0x7f34aa960d30>, 'render': <function StockTradingEnv.render at 0x7f34aa960dc0>, '_initiate_state': <function StockTradingEnv._initiate_state at 0x7f34aa960e50>, '_update_state': <function StockTradingEnv._update_state at 0x7f34aa960ee0>, '_get_date': <function StockTradingEnv._get_date at 0x7f34aa960f70>, 'save_state_memory': <function StockTradingEnv.save_state_memory at 0x7f34aa961000>, 'save_asset_memory': <function StockTradingEnv.save_asset_memory at 0x7f34aa961090>, 'save_action_memory': <function StockTradingEnv.save_action_memory at 0x7f34aa961120>, '_seed': <function StockTradingEnv._seed at 0x7f34aa9611b0>, 'get_sb_env': <function StockTradingEnv.get_sb_env at 0x7f34aa961240>}

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-06        A2C   0.408499   0.221056    0.320418
# 1  189  2021-04-06  2021-07-06        PPO   0.118101   0.199146    0.115579
# 2  252  2021-07-06  2021-10-04       DDPG  -0.039856   -0.13309   -0.011696
# 3  315  2021-10-04  2022-01-03        A2C   0.464181   0.132174    0.026453

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.0854417577576679

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2021-04-06           NaN  2021-04-06
# 1   9.996592e+05  2021-04-07     -0.000341  2021-04-07
# 2   1.000933e+06  2021-04-08      0.001274  2021-04-08
# 3   1.010261e+06  2021-04-09      0.009319  2021-04-09
# 4   1.009559e+06  2021-04-12     -0.000694  2021-04-12

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.002339
# Cumulative returns     0.002339
# Annual volatility      0.137171
# Sharpe ratio           0.085442
# Calmar ratio           0.015591
# Stability              0.059655
# Max drawdown          -0.150026
# Omega ratio            1.014671
# Sortino ratio          0.120035
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.834007
# Daily value at risk   -0.017235
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return          0.037486
# Cumulative returns     0.037335
# Annual volatility      0.134331
# Sharpe ratio           0.342028
# Calmar ratio           0.331049
# Stability              0.066383
# Max drawdown          -0.113235
# Omega ratio            1.058031
# Sortino ratio          0.480831
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.970301
# Daily value at risk   -0.016742
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = '^DJI', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-04-01</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>0.2%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>0.2%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.7%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.09</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.06</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-15.0%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.01</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.12</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.83</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.7%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.03</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.93</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>15.00</td>
#       <td>2021-11-08</td>
#       <td>2022-03-08</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.71</td>
#       <td>2021-06-04</td>
#       <td>2021-06-18</td>
#       <td>2021-07-26</td>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.48</td>
#       <td>2021-09-27</td>
#       <td>2021-09-30</td>
#       <td>2021-10-19</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.43</td>
#       <td>2021-08-27</td>
#       <td>2021-09-21</td>
#       <td>2021-09-23</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.06</td>
#       <td>2021-05-10</td>
#       <td>2021-05-12</td>
#       <td>2021-06-03</td>
#       <td>19</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.00%</td>
#       <td>-2.81%</td>
#       <td>2.82%</td>
#     </tr>
#   </tbody>
# </table>
